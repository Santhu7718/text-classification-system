# %%
import pandas as pd
data_path = "../data/SMSSpamCollection"

df = pd.read_csv(
    data_path,
    sep="\t",
    header=None,
    names=["label", "text"]
)
df.head()
df.shape
df["label"].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64
